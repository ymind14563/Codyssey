# %% [markdown]
# ## 경험적으로 추천해보기
#
# ### 수행단계
#  - 데이터는 제공되는 파일인 prob-0101.csv를 사용한다.
#  - 영화 개수, 배급사 수, 감독 수, 출연진 수, 장르 수를 파악한다.
#  - 감독, 출연진 등 중복 조건들에 대해 파악한다.
#  - 본인이 추천하고 싶은 기준을 설정한다.
#  - 본인의 기준에 의해 영화 몇개를 추천하는 것이 적당한지 실험해 본다.
#  - 다양한 접근 조회 방법을 실험한다. (감독, 출연진 중복, 장르별 등)
#  - 개인별로 정한 기준이 서로 어떻게 다른지 확인한다.

# %%
# %pip install pandas
import pandas as pd
df = pd.read_csv('prob-0101.csv')
# print(df)
# df[['제목', '배급사']]
# Out:
#            개봉일                        제목                  배급사    감독  \
# 0   2023-01-04                       스위치  롯데컬처웍스, (주)롯데엔터테인먼트   마대윤
# 1   2023-01-05                      강남좀비            (주)와이드릴리즈   이수성
# 2   2023-01-12                별 볼일 없는 인생             (주)이놀미디어   서동현
# 3   2023-01-12                  10일간의 애인               (주)그노스   이영용
# 4   2023-01-18                        교섭           플렉스엠엔터테인먼트   임순례
# 5   2023-01-18                        유령            (주)CJ ENM   이해영
# 6   2023-01-20                        정이                 넷플릭스   연상호
# 7   2023-01-25            열여덟, 어른이 되는 나이                필름 다빈    주영
# 8   2023-02-08                     다음 소희            트윈플러스파트너스   정주리
# 9   2023-02-08          어쩌면 우린 헤어졌는지 모른다        (주)영화특별시 에스엠씨   형슬우
# 10  2023-02-08           우리 사랑이 향기로 남을 때   (주)콘텐츠존, (주)다자인소프트   임성용
# 11  2023-02-17           스마트폰을 떨어뜨렸을 뿐인데                 넷플릭스   김태준
# 12  2023-02-22                       카운트            (주)CJ ENM   권혁재
# 13  2023-02-22                        살수         (주)제이앤씨미디어그룹   곽정덕
# 14  2023-02-23                     컨버세이션                필름 다빈   김덕중
# 15  2023-03-01                       멍뭉이        (주)와이웍스엔터테인먼트   김주환
# 16  2023-03-01                       대외비           플러스엠엔터테인먼트   이원태
# 17  2023-03-08                   그대 어이가리            (주)영화사 순수   이창열
# 18  2023-03-15                     소울메이트       (주)넥스트엔터테인먼트월드   민용근
# 19  2023-03-23                    낭만 캠퍼스              (주)콘텐츠윙   박동기
# 20  2023-03-29                   여섯 개의 밤             (주)인디스토리   최창환
# 21  2023-03-29                  여덟 번째 감각             (주)플레이그램   배인우
# 22  2023-03-29                       웅남이            (주)CJ CGV   박성광
# 23  2023-03-29                 찬란한 나의 복수        영화배급협동조합 씨네소파   임성운
# 24  2023-03-29                       흐르다            M&M 인터내셔널   김현정
# 25  2023-04-05                      리바운드           (주)바른손이앤아이   장항준
# 26  2023-04-05                      장기자랑            (주)영화사 진진   이소현
# 27  2023-04-05                  오늘 출가합니다            (주)트리플픽쳐스   김성환
# 28  2023-04-05                    불멸의 여자           드림팩트엔터테인먼트   최종태
# 29  2023-04-06                    솔라 플라워               ㈜스토리제이   한경탁
# 30  2023-04-12                   사랑의 고고학             (주)엣나인필름   이완민
# 31  2023-04-12                    보이지 않아           아웃런브라더스픽쳐스   최세환
# 32  2023-04-12                        제비              (주)시네마달  이송희일
# 8                      다음 소희            트윈플러스파트너스
# 9           어쩌면 우린 헤어졌는지 모른다        (주)영화특별시 에스엠씨
# 10           우리 사랑이 향기로 남을 때   (주)콘텐츠존, (주)다자인소프트
# 11           스마트폰을 떨어뜨렸을 뿐인데                 넷플릭스
# 12                       카운트            (주)CJ ENM
# 13                        살수         (주)제이앤씨미디어그룹
# 14                     컨버세이션                필름 다빈
# 15                       멍뭉이        (주)와이웍스엔터테인먼트
# 16                       대외비           플러스엠엔터테인먼트
# 17                   그대 어이가리            (주)영화사 순수
# 18                     소울메이트       (주)넥스트엔터테인먼트월드
# 19                    낭만 캠퍼스              (주)콘텐츠윙
# 20                   여섯 개의 밤             (주)인디스토리
# 21                  여덟 번째 감각             (주)플레이그램
# 22                       웅남이            (주)CJ CGV
# 23                 찬란한 나의 복수        영화배급협동조합 씨네소파
# 24                       흐르다            M&M 인터내셔널
# 25                      리바운드           (주)바른손이앤아이
# 26                      장기자랑            (주)영화사 진진
# 27                  오늘 출가합니다            (주)트리플픽쳐스
# 28                    불멸의 여자           드림팩트엔터테인먼트
# 29                    솔라 플라워               ㈜스토리제이
# 30                   사랑의 고고학             (주)엣나인필름
# 31                    보이지 않아           아웃런브라더스픽쳐스
# 32                        제비              (주)시네마달
# 33                 나는 여기에 있다            와이드릴리즈(주)
# 34                      물안에서       영화제작전원사, 콘텐츠판다
# 35      밥만 잘 사주는 이상한 이사님 극장판               CJ CGV
# 36                    킬링 로맨스   롯데컬쳐웍스 (주)롯데엔터테인먼트
# 37                    낭만적 공장             (주)영화사오윈
# 38                     튤립 모양               삼거리픽쳐스
# 39                        드림        (주)플렉스엠엔터테인먼트
# 40                      2퍼센트               시네마 뉴원
# 41                        롱디         (주)넥스트엔터테인먼트
# 42                      바람개비             (주)디스테이션
# 43                      스트리머          TCO(주)더콘텐츠온
# 44                말이야 바른 말이지               씨에스픽쳐스
# 45  남자는 처음을 원하고 여자는 마지막을 원한다             (주)스토리제이
# 46                      스프린터             스튜디오 에이드
# 47                     드림팰리스             (주)인디스토리
# 48                    범죄도시 3        (주)에이비오엔터테인먼트
# 49                   박하경 여행기             CJ엔터테인먼트
# 50                 익스트림 페스티벌         트윈플러스파트너스(주)
# 51                     안나푸르나                시네마뉴원
# 52                      육지것들              (주)씨엠닉스
# 53                       실버맨             (주)이놀미디어
# 54                       귀공자       (주)넥스트엔터테인먼트월드
# 55                         손             (주)이눌미디어
# 56                       인드림            (주)원더스튜디오
# 57             아수라장: 범털들의 전쟁         (주)제이앤씨미디어그룹
# 58                        라방               트리플픽쳐스

# %%
import re # 정규식 사용을 위한 모듈

print(f"영화 수: { len(df)}")

# 유니크한 갯수만 출력
print(f"중복 제외 배급사 수: { df['배급사'].nunique() }")
print(f"중복 제외 감독 수: { df['감독'].nunique() }")

# 쉼표(,) 로 구분된 출연진 파악 (ex. (1) 영화1, 영화2의 출연진 목록을 쉼표로 합치고 (2) 전체 합친 것을 쉼표로 나눔, (3) set으로 중복제거하고 (4) len으로 count)
print(f"중복 제외 출연진 수: { len(set(','.join(df['출연진'].dropna()).split(','))) }") # dropna(): 결측값(NaN)을 제거

# 정규식을 사용하여 가운데 점(·), 쉼표(,), 슬래쉬(/)를 전부 쉼표로 바꿈
print(f"중복 제외 장르 수: { len(set(re.split(r'[·,/]', ','.join(df['장르'].dropna())))) }")
# Out:
# 영화 수: 59
# 중복 제외 배급사 수: 52
# 중복 제외 감독 수: 58
# 중복 제외 출연진 수: 268
# 중복 제외 장르 수: 17

# %%
# 추천 기준 점수
# 1. 자주 등장한 배우가 출연한 영화 (40%) 
# - 출연진 중복 점수를 각 배우에게 부여
# - 영화에 출연한 배우의 점수를 합산
# 2. 장르는 드라마와 액션 (40%)
# 3. 최근 개봉일수록 우선 (20%)


from collections import Counter

# 출연진 빈도 계산
all_actors = ','.join(df['출연진']).split(',')  # 중복 포함 전체 배우 목록
actor_frequency = Counter(all_actors) # 빈도 수 계산

# 영화별 출연진 중복 점수 계산
df['출연진_중복점수'] = df['출연진'].apply(lambda cast: sum(actor_frequency[actor] for actor in cast.split(',')))

# print(df[['출연진', '출연진_중복점수']])

# 개봉일 컬럼을 datetime 형식으로 변환
df['개봉일'] = pd.to_datetime(df['개봉일'], errors='coerce')

# 정규화 및 가중치 부여 함수
# 특정 Series 데이터를 0 ~ 1로 정규화하고 가중치를 곱해 반환
def normalize(series, weight):
    return (series - series.min()) / (series.max() - series.min()) * weight
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 12
#       9 from collections import Counter
#      11 # 출연진 빈도 계산
# ---> 12 all_actors = ','.join(df['출연진']).split(',')  # 중복 포함 전체 배우 목록
#      13 actor_frequency = Counter(all_actors) # 빈도 수 계산
#      15 # 영화별 출연진 중복 점수 계산
#
# NameError: name 'df' is not defined

# %%
# 추천 점수 계산
df['추천점수'] = (
    normalize(df['출연진_중복점수'], 0.4) +
    df['장르'].apply(lambda x: 1 if any(genre in ['드라마', '멜로'] for genre in re.split(r'[·,/]', x)) else 0) * 0.4 +
    normalize((df['개봉일'] - df['개봉일'].min()).dt.days, 0.2)
)

print(df[['제목', '추천점수']])
# Out:
#                           제목      추천점수
# 0                        스위치  0.080000
# 1                       강남좀비  0.421143
# 2                 별 볼일 없는 인생  0.409143
# 3                   10일간의 애인  0.409143
# 4                         교섭  0.456000
# 5                         유령  0.136000
# 6                         정이  0.058286
# 7             열여덟, 어른이 되는 나이  0.484000
# 8                      다음 소희  0.500000
# 9           어쩌면 우린 헤어졌는지 모른다  0.500000
# 10           우리 사랑이 향기로 남을 때  0.540000
# 11           스마트폰을 떨어뜨렸을 뿐인데  0.090286
# 12                       카운트  0.596000
# 13                        살수  0.136000
# 14                     컨버세이션  0.557143
# 15                       멍뭉이  0.484000
# 16                       대외비  0.104000
# 17                   그대 어이가리  0.512000
# 18                     소울메이트  0.520000
# 19                    낭만 캠퍼스  0.609143
# 20                   여섯 개의 밤  0.596000
# 21                  여덟 번째 감각  0.616000
# 22                       웅남이  0.276000
# 23                 찬란한 나의 복수  0.536000
# 24                       흐르다  0.516000
# 25                      리바운드  0.524000
# 26                      장기자랑  0.224000
# 27                  오늘 출가합니다  0.524000
# 28                    불멸의 여자  0.544000
# 29                    솔라 플라워  0.665143
# 30                   사랑의 고고학  0.552000
# 31                    보이지 않아  0.612000
# 32                        제비  0.632000
# 33                 나는 여기에 있다  0.232000
# 34                      물안에서  0.592000
# 35      밥만 잘 사주는 이상한 이사님 극장판  0.532000
# 36                    킬링 로맨스  0.174286
# 37                    낭만적 공장  0.580000
# 38                     튤립 모양  0.620000
# 39                        드림  0.788000
# 40                      2퍼센트  0.549143
# 41                        롱디  0.564000
# 42                      바람개비  0.224000
# 43                      스트리머  0.224000
# 44                말이야 바른 말이지  0.372000
# 45  남자는 처음을 원하고 여자는 마지막을 원한다  0.593143
# 46                      스프린터  0.280000
# 47                     드림팰리스  0.628000
# 48                    범죄도시 3  0.568000
# 49                   박하경 여행기  0.576000
# 50                 익스트림 페스티벌  0.216000
# 51                     안나푸르나  0.657143
# 52                      육지것들  0.177143
# 53                       실버맨  0.684000
# 54                       귀공자  0.252000
# 55                         손  0.292000
# 56                       인드림  0.272000
# 57             아수라장: 범털들의 전쟁  0.260000
# 58                        라방  0.260000

# %%
# 출연진 점수 출력
print("\n출연진과 출연진 중복 점수:")
print(df[['출연진', '출연진_중복점수']])

# 장르 점수 출력
print("\n장르와 관련된 점수:")
df['장르_점수'] = df['장르'].apply(
    lambda x: 1 if any(genre in ['드라마', '액션'] for genre in re.split(r'[·,/]', x)) else 0 # 정규식 사용
) * 0.4
print(df[['장르', '장르_점수']])

# 개봉일 점수 출력
print("\n개봉일과 개봉일 관련 점수:")
df['개봉일_점수'] = normalize((df['개봉일'] - df['개봉일'].min()).dt.days, 0.2)
print(df[['개봉일', '개봉일_점수']])
# Out:
# 출연진과 출연진 중복 점수:
#                                                   출연진  출연진_중복점수
# 0                              권상우, 오정세, 이민정, 박소이, 김준         5
# 1                                             지일주, 지연         2
# 2                                                 정가은         1
# 3                                                 송민경         1
# 4                                        황정민, 현빈, 강기영         3
# 5                        설경구, 이하늬, 박소감, 박해수, 서현우, 김동희         7
# 6                                       강수연, 김현주, 류경수         3
# 7                                  임선우, 김명찬, 이장유, 박현숙         4
# 8                                  김시은, 배두나, 박우영, 정수하         4
# 9                                  이동휘, 정은채, 강길우, 정다은         4
# 10                       윤시윤, 설인아, 노상현, 문지인, 이규복, 김영웅         6
# 11                                      천우희, 임시완, 김희원         3
# 12                       진선규, 성유빈, 오나라, 고창석, 장동주, 고규필         8
# 13                            신현준, 이문식, 김민경, 홍은기, 최성원         5
# 14                        조은지, 박종환, 곽민규, 소이, 송은지, 곽진무         6
# 15                                           유연석, 차태현         2
# 16                                      조진웅, 이성민, 김무열         3
# 17                                      선동혁, 정아미, 박종진         3
# 18                                      김다미, 전소니, 변우석         3
# 19                  신민재, 송보은, 이경욱, 설유진, 현진영, 박동기, 김세환         7
# 20                       강길우, 강진아, 김시은, 변중희, 이한주, 정수지         6
# 21                  오준택, 임지섭, 박해인, 장영준, 방진원, 서지안, 채수아         7
# 22        박성웅, 이이경, 염혜란, 최민수, 오달수, 윤제문, 백지혜, 서동원, 한다솔        10
# 23                                      허준석, 이영석, 남보라         3
# 24                                            이설, 박지수         2
# 25                                           안재홍, 양한열         2
# 26                  김명임, 김도현, 김순덕, 박유신, 이미경, 최지연, 박혜영         7
# 27                                           양홍주, 나현준         2
# 28                                       이음, 윤가현, 인내상         3
# 29         오원빈, 서지희, 심현탁, 박정철, 김수하, 김민, 김봉주, 조수빈, 정병훈         9
# 30                                       옥자연, 기윤, 하민호         3
# 31                       박호산, 신애리, 백수련, 이노아, 정혜인, 이용녀         6
# 32                   윤박, 우지현, 박미현, 장희령, 이대연, 박소진, 유인수         7
# 33                 조한선, 정지운, 정태우, 노수산나, 박순천, 정인기, 이지원         7
# 34                            신석호, 하성국, 김승윤, 김민희, 김소령         5
# 35                                           박정우, 박영훈         2
# 36                                  이하늬, 이선균, 공명, 김상욱         4
# 37                                 심희섭, 전혜진, 한승도, 박수영         4
# 38                       유다인, 김다현, 문희경, 김정균, 진혜원, 이지용         6
# 39   박서준, 아이유, 김종수, 고창석, 정승길, 이현우, 양현민, 홍완표, 허준석, 이하늬        14
# 40                                           허지나, 남명렬         2
# 41                                           장동윤, 박유나         2
# 42                            차선우, 유지애, 김소희, 이원석, 서지후         5
# 43                            이푸름, 권민혁, 김준형, 심소영, 김모범         5
# 44   김경일, 양현민, 김소형, 김우겸, 정승길, 조윤서, 신사랑, 오경화, 서벽준, 정유연        12
# 45                                      윤성모, 정미미, 장원혁         3
# 46                  박성일, 공민정, 임지호, 전신환, 송덕호, 최준혁, 한태경         7
# 47                                 김선영, 이윤지, 최민영, 김용준         4
# 48  마동석, 이준혁, 아오키 무네타카, 이범수, 김민재, 이지훈, 김도건, 최동구, 이...        21
# 49                                                이나영         1
# 50                                      김재화, 조민재, 박강섭         3
# 51                            김강현, 차선우, 한수연, 신연서, 서은채         5
# 52                                                 소이         1
# 53                            김정팔, 박상욱, 신의현, 이경준, 유재인         6
# 54                                 김선호, 강태주, 김강우, 고아라         4
# 55                             이재원, 박상욱, 정서하, 허웅, 안수호         6
# 56                            서효림, 오지호, 김승수, 이설구, 노지유         5
# 57                                 정영주, 안미나, 배진아, 한가은         4
# 58                                      박성웅, 박선호, 김희정         4
#
# 장르와 관련된 점수:
#                  장르  장르_점수
# 0                기타    0.0
# 1               드라마    0.4
# 2            멜로/로맨스    0.0
# 3            멜로/로맨스    0.0
# 4               드라마    0.4
# 5                액션    0.4
# 6                SF    0.0
# 7               드라마    0.4
# 8               드라마    0.4
# 9               드라마    0.4
# 10       멜로·로맨스·코미디    0.0
# 11              스릴러    0.0
# 12              드라마    0.4
# 13               액션    0.4
# 14              드라마    0.4
# 15              드라마    0.4
# 16          범죄, 드라마    0.0
# 17              드라마    0.4
# 18              드라마    0.4
# 19              드라마    0.4
# 20  드라마, 멜로·로맨스, 가족    0.4
# 21           멜로·로맨스    0.0
# 22          코미디, 액션    0.0
# 23              드라마    0.4
# 24              드라마    0.4
# 25              드라마    0.4
# 26            다큐멘터리    0.0
# 27              드라마    0.4
# 28              드라마    0.4
# 29       멜로,로맨스,드라마    0.4
# 30              드라마    0.4
# 31              드라마    0.4
# 32              드라마    0.4
# 33        범죄·액션·스럴리    0.4
# 34              드라마    0.4
# 35           드라마,멜로    0.4
# 36              코미디    0.0
# 37           멜로·로맨스    0.0
# 38              드라마    0.4
# 39              드라마    0.4
# 40              드라마    0.4
# 41       멜로·로맨스·코미디    0.0
# 42               액션    0.4
# 43          공포·미스터리    0.0
# 44              코미디    0.0
# 45           멜로·로맨스    0.0
# 46               기타    0.0
# 47              드라마    0.4
# 48           범죄, 액션    0.0
# 49              드라마    0.4
# 50              코미디    0.0
# 51              드라마    0.4
# 52              코미디    0.0
# 53              드라마    0.4
# 54               액션    0.4
# 55           공포,코미디    0.0
# 56               액션    0.4
# 57               범죄    0.0
# 58              스릴러    0.0
#
# 개봉일과 개봉일 관련 점수:
#           개봉일    개봉일_점수
# 0  2023-01-04  0.000000
# 1  2023-01-05  0.001143
# 2  2023-01-12  0.009143
# 3  2023-01-12  0.009143
# 4  2023-01-18  0.016000
# 5  2023-01-18  0.016000
# 6  2023-01-20  0.018286
# 7  2023-01-25  0.024000
# 8  2023-02-08  0.040000
# 9  2023-02-08  0.040000
# 10 2023-02-08  0.040000
# 11 2023-02-17  0.050286
# 12 2023-02-22  0.056000
# 13 2023-02-22  0.056000
# 14 2023-02-23  0.057143
# 15 2023-03-01  0.064000
# 16 2023-03-01  0.064000
# 17 2023-03-08  0.072000
# 18 2023-03-15  0.080000
# 19 2023-03-23  0.089143
# 20 2023-03-29  0.096000
# 21 2023-03-29  0.096000
# 22 2023-03-29  0.096000
# 23 2023-03-29  0.096000
# 24 2023-03-29  0.096000
# 25 2023-04-05  0.104000
# 26 2023-04-05  0.104000
# 27 2023-04-05  0.104000
# 28 2023-04-05  0.104000
# 29 2023-04-06  0.105143
# 30 2023-04-12  0.112000
# 31 2023-04-12  0.112000
# 32 2023-04-12  0.112000
# 33 2023-04-12  0.112000
# 34 2023-04-12  0.112000
# 35 2023-04-12  0.112000
# 36 2023-04-14  0.114286
# 37 2023-04-19  0.120000
# 38 2023-04-19  0.120000
# 39 2023-04-26  0.128000
# 40 2023-04-27  0.129143
# 41 2023-05-10  0.144000
# 42 2023-05-10  0.144000
# 43 2023-05-10  0.144000
# 44 2023-05-17  0.152000
# 45 2023-05-18  0.153143
# 46 2023-05-24  0.160000
# 47 2023-05-31  0.168000
# 48 2023-05-31  0.168000
# 49 2023-06-07  0.176000
# 50 2023-06-07  0.176000
# 51 2023-06-08  0.177143
# 52 2023-06-08  0.177143
# 53 2023-06-14  0.184000
# 54 2023-06-21  0.192000
# 55 2023-06-21  0.192000
# 56 2023-06-21  0.192000
# 57 2023-06-28  0.200000
# 58 2023-06-28  0.200000

# %%
# 추천 영화 정렬 및 상위 3개 출력
recommended_movies = df.sort_values(by='추천점수', ascending=False).head(3)
print(recommended_movies[['제목', '감독', '출연진', '장르', '추천점수']])
# Out:
#         제목   감독                                               출연진          장르  \
# 39      드림  이병헌  박서준, 아이유, 김종수, 고창석, 정승길, 이현우, 양현민, 홍완표, 허준석, 이하늬         드라마
# 53     실버맨  최윤호                           김정팔, 박상욱, 신의현, 이경준, 유재인         드라마
# 29  솔라 플라워  한경탁        오원빈, 서지희, 심현탁, 박정철, 김수하, 김민, 김봉주, 조수빈, 정병훈  멜로,로맨스,드라마
#
#         추천점수
# 39  0.788000
# 53  0.684000
# 29  0.665143
